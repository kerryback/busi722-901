# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 10
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'':
  os.chdir(r'')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# C:\Users\kerry\AppData\Local\Temp\ipykernel_5740\1140549349.py:20: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats(fig_format)
# {"C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap_external.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\codecs.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\aliases.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\utf_8.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\cp1252.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\io.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\stat.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_collections_abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\genericpath.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\ntpath.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\os.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_sitebuiltins.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_distutils_hack\\__init__.py": 1665541945.6758869, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\types.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\warnings.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\keyword.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\operator.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\reprlib.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\functools.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\contextlib.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\util.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\machinery.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32\\lib\\pywin32_bootstrap.py": 1665545610.7738168, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\runpy.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\enum.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_constants.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_parse.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_compile.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\copyreg.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\re.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\typing.py": 1665532704.0, "C:\\Users\\kerry\\AppData\ ...

# %%
import pandas as pd
import pymssql
from sqlalchemy import create_engine

server = 'fs.rice.edu'
database = 'stocks'
username = 'stocks'
password = '6LAZH1'

string = "mssql+pymssql://" + username + ":" + password + "@" + server + "/" + database 
conn = create_engine(string).connect()

df = pd.read_sql(
    "select * from information_schema.tables",
    conn
)
df
# Out:
#   TABLE_CATALOG TABLE_SCHEMA  TABLE_NAME  TABLE_TYPE
# 0        stocks          dbo        sep2  BASE TABLE
# 1        stocks          dbo       today  BASE TABLE
# 2        stocks          dbo  indicators  BASE TABLE
# 3        stocks          dbo     tickers  BASE TABLE
# 4        stocks          dbo         sf1  BASE TABLE
# 5        stocks          dbo         sep  BASE TABLE
# 6        stocks          dbo       daily  BASE TABLE

# %%
df = pd.read_sql(
    "select * from indicators",
    conn
)
df.to_excel("indicators.xlsx")

# %%
df = pd.read_sql(
    """
    select * from sf1 
    where ticker='AAPL' and dimension='ARY'
    order by reportperiod
    """, 
    conn
)
df
# Out:
#   ticker dimension calendardate     datekey reportperiod lastupdated  \
# 0   AAPL       ARY   2019-12-31  2019-10-31   2019-09-28  2022-10-28
# 1   AAPL       ARY   2020-12-31  2020-10-30   2020-09-26  2022-10-28
# 2   AAPL       ARY   2021-12-31  2021-10-29   2021-09-25  2022-10-28
# 3   AAPL       ARY   2022-12-31  2022-10-28   2022-09-24  2022-10-28
#
#          accoci        assets     assetsavg       assetsc  ...     sharesbas  \
# 0 -5.840000e+08  3.385160e+11  3.441180e+11  1.628190e+11  ...  1.777306e+10
# 1 -4.060000e+08  3.238880e+11  3.255625e+11  1.437130e+11  ...  1.700180e+10
# 2  1.630000e+08  3.510020e+11  3.430135e+11  1.348360e+11  ...  1.640640e+10
# 3 -1.110900e+10  3.527550e+11  3.552292e+11  1.354050e+11  ...  1.590812e+10
#
#        shareswa   shareswadil     sps     tangibles  taxassets        taxexp  \
# 0  1.847134e+10  1.859565e+10  14.085  3.385160e+11        0.0  1.048100e+10
# 1  1.735212e+10  1.752821e+10  15.820  3.238880e+11        0.0  9.680000e+09
# 2  1.670127e+10  1.686492e+10  21.904  3.510020e+11        0.0  1.452700e+10
# 3  1.621596e+10  1.632582e+10  24.317  3.527550e+11        0.0  1.930000e+10
#
#    taxliabilities   tbvps  workingcapital
# 0             0.0  18.327    5.710100e+10
# 1             0.0  18.666    3.832100e+10
# 2             0.0  21.016    9.355000e+09
# 3             0.0  21.754   -1.857700e+10
#
# [4 rows x 111 columns]

# %%
df = pd.read_sql(
    """
    select * from sf1 
    where ticker in ('AAPL', 'CVX') and dimension='ARQ' and reportperiod>='2020-01-01'
    order by ticker, reportperiod
    """, 
    conn
)
df
# Out:
#    ticker dimension calendardate     datekey reportperiod lastupdated  \
# 0    AAPL       ARQ   2020-03-31  2020-05-01   2020-03-28  2022-10-28
# 1    AAPL       ARQ   2020-06-30  2020-07-31   2020-06-27  2022-10-28
# 2    AAPL       ARQ   2020-09-30  2020-10-30   2020-09-26  2022-10-28
# 18    1.777400e+10  120.741    6.947000e+09
# 19    1.930400e+10  126.403    1.350600e+10
# 20    2.021700e+10  130.037    1.206700e+10
# 21    2.239800e+10  132.009    1.462000e+10
#
# [22 rows x 111 columns]

# %%
df = pd.read_sql(
    """
    select * from sep where ticker='AAPL' 
    order by date
    """,
    conn
)
df
# Out:
#      ticker        date lastupdated    open_     high      low   close_  \
# 0      AAPL  2019-01-02  2022-12-27   38.722   39.712   38.557   39.480
# 1      AAPL  2019-01-03  2022-12-27   35.995   36.430   35.500   35.547
# 2      AAPL  2019-01-04  2022-12-27   36.133   37.138   35.950   37.065
# 3      AAPL  2019-01-07  2022-12-27   37.175   37.208   36.475   36.983
# 4      AAPL  2019-01-08  2022-12-27   37.390   37.955   37.130   37.688
# ...     ...         ...         ...      ...      ...      ...      ...
# 1012   AAPL  2023-01-09  2023-01-09  130.465  133.410  129.890  130.150
# 1013   AAPL  2023-01-10  2023-01-10  130.260  131.264  128.120  130.730
# 1014   AAPL  2023-01-11  2023-01-11  131.250  133.510  130.460  133.490
# 1015   AAPL  2023-01-12  2023-01-12  133.880  134.260  131.440  133.410
# 1016   AAPL  2023-01-13  2023-01-13  132.030  134.920  131.660  134.760
#
#            volume  closeadj  closeunadj
# 0     148158948.0    38.055      157.92
# 1     365248780.0    34.264      142.19
# 2     234428280.0    35.727      148.26
# 3     219111056.0    35.647      147.93
# 4     164101256.0    36.327      150.75
# ...           ...       ...         ...
# 1012   70496600.0   130.150      130.15
# 1013   63427651.0   130.730      130.73
# 1014   69114397.0   133.490      133.49
# 1015   71247695.0   133.410      133.41
# 1016   57618588.0   134.760      134.76
#
# [1017 rows x 10 columns]

# %%
df = pd.read_sql(
    """
    select * from daily where ticker='AAPL' 
    order by date
    """,
    conn
)
df
# Out:
#      ticker        date lastupdated         ev  evebit  evebitda  marketcap  \
# 0      AAPL  2019-01-02  2021-12-19   837963.3    11.0       9.6   749393.3
# 1      AAPL  2019-01-03  2021-12-19   763308.7    10.0       8.8   674738.7
# 2      AAPL  2019-01-04  2021-12-19   792122.7    10.4       9.1   703552.7
# 3      AAPL  2019-01-07  2021-12-19   790566.2    10.4       9.1   701996.2
# 4      AAPL  2019-01-08  2021-12-19   803948.2    10.6       9.2   715378.2
# ...     ...         ...         ...        ...     ...       ...        ...
# 1012   AAPL  2023-01-09  2023-01-09  2166864.6    17.8      16.3  2070441.6
# 1013   AAPL  2023-01-10  2023-01-10  2176091.3    17.8      16.3  2079668.3
# 1014   AAPL  2023-01-11  2023-01-11  2219997.7    18.2      16.7  2123574.7
# 1015   AAPL  2023-01-12  2023-01-12  2218725.0    18.2      16.7  2122302.0
# 1016   AAPL  2023-01-13  2023-01-13  2240201.0    18.4      16.8  2143778.0
#
#         pb    pe   ps
# 0      7.0  12.6  2.8
# 1      6.3  11.3  2.5
# 2      6.6  11.8  2.6
# 3      6.6  11.8  2.6
# 4      6.7  12.0  2.7
# ...    ...   ...  ...
# 1012  40.9  20.7  5.3
# 1013  41.0  20.8  5.3
# 1014  41.9  21.3  5.4
# 1015  41.9  21.3  5.4
# 1016  42.3  21.5  5.4
#
# [1017 rows x 10 columns]
