# %%
import pandas as pd 
from sqlalchemy import create_engine
server = 'rice-sqlcl-db'
database = 'SharadarEquity'
username = 'stocks'
password = '6LAZH1'
string = f"mssql+pymssql://{username}:{password}@{server}/{database}"
conn = create_engine(string).connect() 
df = pd.read_sql("select * from ghz", conn)
df = df.dropna(subset=["date"])
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# File src\\pymssql\\_pymssql.pyx:650, in pymssql._pymssql.connect()
#
# File src\\pymssql\\_mssql.pyx:2158, in pymssql._mssql.connect()
#
# File src\\pymssql\\_mssql.pyx:712, in pymssql._mssql.MSSQLConnection.__init__()
#
# File src\\pymssql\\_mssql.pyx:1884, in pymssql._mssql.maybe_raise_MSSQLDatabaseException()
#
# File src\\pymssql\\_mssql.pyx:1901, in pymssql._mssql.raise_MSSQLDatabaseException()
#
# MSSQLDatabaseException: (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (rice-sqlcl-db)\n')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
df.date.unique()
# Out:
# array([datetime.date(2025, 3, 21)], dtype=object)

# %%
import pandas as pd 
df = pd.read_sql("select * from information_schema.tables", conn)

# %%
df
# Out:
#     TABLE_CATALOG TABLE_SCHEMA    TABLE_NAME  TABLE_TYPE
# 0  SharadarEquity          dbo           ghz  BASE TABLE
# 1  SharadarEquity          dbo   definitions  BASE TABLE
# 2  SharadarEquity          dbo       tickers  BASE TABLE
# 3  SharadarEquity          dbo        prices  BASE TABLE
# 4  SharadarEquity          dbo  fundamentals  BASE TABLE
# 5  SharadarEquity          dbo       metrics  BASE TABLE
# 6  SharadarEquity          dbo         today  BASE TABLE

# %%
df2 = pd.read_sql("select * from ghz", conn)

# %%
df2 = df2.dropna(subset=["date"])

# %%
df2
# Out:
#         siccd        date      roeq      roaq       acc       agr        bm  \
# 0      3826.0  2025-03-21  0.053917  0.026845 -0.041392  0.100623  0.153532
# 1      3334.0  2025-03-21  0.038476  0.013891 -0.039273 -0.006429  0.534768
# 10     6770.0  2025-03-21       NaN       NaN       NaN       NaN       NaN
# 19     4512.0  2025-03-21       NaN       NaN       NaN       NaN       NaN
# 20     6770.0  2025-03-21       NaN       NaN       NaN       NaN       NaN
# ...       ...         ...       ...       ...       ...       ...       ...
# 15077  2834.0  2025-03-21  0.111005  0.040468 -0.032711 -0.003430  0.064587
# 15079  5600.0  2025-03-21  0.046530  0.022840 -0.034390 -0.044179  1.343560
# 15084  2834.0  2025-03-21 -0.512240 -0.186577 -0.215495  0.033657  0.092548
# 15089  3560.0  2025-03-21  0.022944  0.013458 -0.049836 -0.006937  0.245618
# 15091  2834.0  2025-03-21 -0.064053 -0.048252 -0.025056 -0.202777  0.369421
#
#              ep       gma       lev  ...  ticker  \
# ...
